# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('./data/churn.xls', sheet_name='churn')

# %%
df.head()
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  Day Charge  Eve Calls  \
# 0               1      0           0           1  ...       45.07         99
# 1               1      0           0           1  ...       27.47        103
# 2               0      0           0           0  ...       41.38        110
# 3               2      0           1           0  ...       50.90         88
# 4               3      0           1           0  ...       28.34        122
#
# ...

# %%
df.tail()
# Out:
#       Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  \
# 3328             192             36     156.2     215.5       279.1
# 3329              68              0     231.1     153.4       191.3
# 3330              28              0     180.8     288.8       191.9
# 3331             184              0     213.8     159.6       139.2
# 3332              74             25     234.4     265.9       241.4
#
#       Intl Mins  CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  \
# 3328        9.9               2      0           0           1  ...
# 3329        9.6               3      0           0           0  ...
# 3330       14.1               2      0           0           0  ...
# 3331        5.0               2      0           1           0  ...
# 3332       13.7               0      0           0           1  ...
#
#       Day Charge  Eve Calls  Eve Charge  Night Calls  Night Charge  \
# 3328       26.55        126       18.32           83         12.56
# ...

# %% [markdown]
# ## Basic statistics

# %% [markdown]
# Now we will look at some basic functions. But first, some `Markdown`:
#
# - One
# - Two
# - Three
#
# # Main
#
# ## Secondary
#
# **Bold**
#
# *Italic*

# %%
df.info() # Overview of types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# Account Length    3333 non-null int64
# VMail Message     3333 non-null int64
# Day Mins          3333 non-null float64
# Eve Mins          3333 non-null float64
# Night Mins        3333 non-null float64
# Intl Mins         3333 non-null float64
# CustServ Calls    3333 non-null int64
# Churn             3333 non-null int64
# Int'l Plan        3333 non-null int64
# VMail Plan        3333 non-null int64
# Day Calls         3333 non-null int64
# Day Charge        3333 non-null float64
# Eve Calls         3333 non-null int64
# Eve Charge        3333 non-null float64
# Night Calls       3333 non-null int64
# Night Charge      3333 non-null float64
# Intl Calls        3333 non-null int64
# Intl Charge       3333 non-null float64
# State             3333 non-null object
# Area Code         3333 non-null int64
# Phone             3333 non-null object
# ...

# %%
df.describe()
# Out:
#        Account Length  VMail Message     Day Mins     Eve Mins   Night Mins  \
# count     3333.000000    3333.000000  3333.000000  3333.000000  3333.000000
# mean       101.064806       8.099010   179.775098   200.980348   200.872037
# std         39.822106      13.688365    54.467389    50.713844    50.573847
# min          1.000000       0.000000     0.000000     0.000000    23.200000
# 25%         74.000000       0.000000   143.700000   166.600000   167.000000
# 50%        101.000000       0.000000   179.400000   201.400000   201.200000
# 75%        127.000000      20.000000   216.400000   235.300000   235.300000
# max        243.000000      51.000000   350.800000   363.700000   395.000000
#
#          Intl Mins  CustServ Calls        Churn   Int'l Plan   VMail Plan  \
# count  3333.000000     3333.000000  3333.000000  3333.000000  3333.000000
# mean     10.237294        1.562856     0.144914     0.096910     0.276628
# ...

# %% [markdown]
# ## Selecting subsets of the data

# %%
df.head()
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  Day Charge  Eve Calls  \
# 0               1      0           0           1  ...       45.07         99
# 1               1      0           0           1  ...       27.47        103
# 2               0      0           0           0  ...       41.38        110
# 3               2      0           1           0  ...       50.90         88
# 4               3      0           1           0  ...       28.34        122
#
# ...

# %%
df.iloc[1:4, 2:5]
# Out:
#    Day Mins  Eve Mins  Night Mins
# 1     161.6     195.5       254.4
# 2     243.4     121.2       162.6
# 3     299.4      61.9       196.9

# %%
df.iloc[1:4, 2:5].describe() # Chain with any operation that can be applied to a df
# Out:
#          Day Mins    Eve Mins  Night Mins
# count    3.000000    3.000000    3.000000
# mean   234.800000  126.200000  204.633333
# std     69.301371   66.940197   46.386025
# min    161.600000   61.900000  162.600000
# 25%    202.500000   91.550000  179.750000
# 50%    243.400000  121.200000  196.900000
# 75%    271.400000  158.350000  225.650000
# max    299.400000  195.500000  254.400000

# %% [markdown]
# **Filtering with explicit dependence to variable names**

# %%
df.columns
# Out:
# Index(['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins',
#        'Intl Mins', 'CustServ Calls', 'Churn', 'Int'l Plan', 'VMail Plan',
#        'Day Calls', 'Day Charge', 'Eve Calls', 'Eve Charge', 'Night Calls',
#        'Night Charge', 'Intl Calls', 'Intl Charge', 'State', 'Area Code',
#        'Phone'],
#       dtype='object')

# %%
df[['Day Mins', 'Eve Mins', 'Night Mins']].head()
# Out:
#    Day Mins  Eve Mins  Night Mins
# 0     265.1     197.4       244.7
# 1     161.6     195.5       254.4
# 2     243.4     121.2       162.6
# 3     299.4      61.9       196.9
# 4     166.7     148.3       186.9

# %%
df.loc[1:3,['Day Mins', 'Eve Mins', 'Night Mins']] # Row index is inclusive here!
# Out:
#    Day Mins  Eve Mins  Night Mins
# 1     161.6     195.5       254.4
# 2     243.4     121.2       162.6
# 3     299.4      61.9       196.9

# %%
small_df = df.loc[1:,['Day Mins', 'Eve Mins', 'Night Mins']].copy() #force a hard copy

# %%
small_df.std() # .min(), .max(), .mean(), .median(), .std()
# Out:
# Day Mins      54.455494
# Eve Mins      50.721418
# Night Mins    50.575735
# dtype: float64

# %% [markdown]
# ## More sophisticated filtering
#
# Filter on rows/columns that satisfy certain conditions

# %%
df.columns
# Out:
# Index(['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins',
#        'Intl Mins', 'CustServ Calls', 'Churn', 'Int'l Plan', 'VMail Plan',
#        'Day Calls', 'Day Charge', 'Eve Calls', 'Eve Charge', 'Night Calls',
#        'Night Charge', 'Intl Calls', 'Intl Charge', 'State', 'Area Code',
#        'Phone'],
#       dtype='object')

# %%
# Choose customers that have been our clients for over 1 month?
df[df['Account Length'] > 30]
# Out:
#       Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  \
# 0                128             25     265.1     197.4       244.7
# 1                107             26     161.6     195.5       254.4
# 2                137              0     243.4     121.2       162.6
# 3                 84              0     299.4      61.9       196.9
# 4                 75              0     166.7     148.3       186.9
# ...              ...            ...       ...       ...         ...
# 3327              79              0     134.7     189.7       221.4
# 3328             192             36     156.2     215.5       279.1
# 3329              68              0     231.1     153.4       191.3
# 3331             184              0     213.8     159.6       139.2
# 3332              74             25     234.4     265.9       241.4
#
#       Intl Mins  CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  \
# 0          10.0               1      0           0           1  ...
# ...

# %%
df.shape
# Out:
# (3333, 21)

# %%
df.head()
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  Day Charge  Eve Calls  \
# 0               1      0           0           1  ...       45.07         99
# 1               1      0           0           1  ...       27.47        103
# 2               0      0           0           0  ...       41.38        110
# 3               2      0           1           0  ...       50.90         88
# 4               3      0           1           0  ...       28.34        122
#
# ...

# %% [markdown]
# ## Set up a custom index

# %%
df.columns
# Out:
# Index(['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins',
#        'Intl Mins', 'CustServ Calls', 'Churn', 'Int'l Plan', 'VMail Plan',
#        'Day Calls', 'Day Charge', 'Eve Calls', 'Eve Charge', 'Night Calls',
#        'Night Charge', 'Intl Calls', 'Intl Charge', 'State', 'Area Code',
#        'Phone'],
#       dtype='object')

# %%
df.index = df['Phone'] # Set up some custom index to our data

# %%
df.head()
# Out:
#           Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  \
# Phone
# 382-4657             128             25     265.1     197.4       244.7
# 371-7191             107             26     161.6     195.5       254.4
# 358-1921             137              0     243.4     121.2       162.6
# 375-9999              84              0     299.4      61.9       196.9
# 330-6626              75              0     166.7     148.3       186.9
#
#           Intl Mins  CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  \
# Phone                                                               ...
# 382-4657       10.0               1      0           0           1  ...
# 371-7191       13.7               1      0           0           1  ...
# 358-1921       12.2               0      0           0           0  ...
# 375-9999        6.6               2      0           1           0  ...
# 330-6626       10.1               3      0           1           0  ...
#
# ...

# %%
df.loc[['382-4657','375-9999'], ['Account Length', 'CustServ Calls']]
# Out:
#           Account Length  CustServ Calls
# Phone
# 382-4657             128               1
# 375-9999              84               2

# %% [markdown]
# ## Filtering in more than one condition

# %%
df[(df['Account Length']>30) & (df['CustServ Calls']>0)].head() #&:AND,|:OR
# Out:
#           Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  \
# Phone
# 382-4657             128             25     265.1     197.4       244.7
# 371-7191             107             26     161.6     195.5       254.4
# 358-1921             137              0     243.4     121.2       162.6
# 375-9999              84              0     299.4      61.9       196.9
# 330-6626              75              0     166.7     148.3       186.9
#
#           Intl Mins  CustServ Calls  Churn  Int'l Plan  VMail Plan  ...  \
# Phone                                                               ...
# 382-4657       10.0               1      0           0           1  ...
# 371-7191       13.7               1      0           0           1  ...
# 358-1921       12.2               0      0           0           0  ...
# 375-9999        6.6               2      0           1           0  ...
# 330-6626       10.1               3      0           1           0  ...
#
# ...

# %%
df[(df['Account Length']>30) & (df['CustServ Calls']>0)][['Eve Calls', 'Night Calls']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000196387FB708>,
# ...
#       dtype=object)
